# %% [markdown]
# <a href="https://colab.research.google.com/github/thaissanchesroque/Modulo-1/blob/main/1_5_Listas_de_valores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Listas, tuplas e dicionários

# %%
# Lista
[1,2,3,4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Tupla
(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Dicionário
{'num1': 1, 'num2': 2}
# Out:
# {'num1': 1, 'num2': 2}

# %% [markdown]
# # Lista

# %%
lista = [5, 'Rodrigo', 8.9]

# %%
type(lista)
# Out:
# list

# %%
lista.append("Guilherme") # Adicionar elemento na lista

# %%
print(lista)
print(lista[1])
# Out:
# [5, 'Rodrigo', 8.9, 'Guilherme']
# Rodrigo

# %% [markdown]
# # Tupla

# %%
tupla = (5, 'Rodrigo', 8.9)

# %%
tipe = (tupla)

# %%
tuple.append("Augusto")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31747/2187949476.py in <cell line: 0>()
# ----> 1 tuple.append("Augusto")
#
# AttributeError: type object 'tuple' has no attribute 'append'

# %%
print=(tuple)

# %% [markdown]
# # Dicionário

# %%
dicionario = {'nome':'Rodrigo','cidade':'São José dos Campos'}

# %%
type(dicionario)
# Out:
# dict

# %%
print(dicionario)
# Out:
# ('nome', 'cidade')

# %%
print(dicionario["nome"])
# Out:
# ('R', 'o', 'd', 'r', 'i', 'g', 'o')

# %%
dicionario['ultimo_nome'] = 'Reboucas'

# %%
print(dicionario)
# Out:
# ('nome', 'cidade', 'ultimo_nome')
