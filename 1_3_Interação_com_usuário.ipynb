# %% [markdown]
# <a href="https://colab.research.google.com/github/thaissanchesroque/Modulo-1/blob/main/1_3_Intera%C3%A7%C3%A3o_com_usu%C3%A1rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualização de Variáveis e textos

# %%
print("Conhecendo o comando Print")

x = 8
print(x)
# Out:
# Conhecendo o comando Print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = 'Thaís Sanches'
print(nome)
# Out:
# Thaís Sanches

# %% [markdown]
# Concatenação

# %%
x = 5
print('O valor de x é', x)
# Out:
# O valor de x é 5

# %%
print('O valor de x é', x , 'e o dobro é', x * 2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print('Eu,', nome, 'tirei', x, 'na prova de Python')
# Out:
# Eu, Thaís Sanches tirei 5 na prova de Python

# %%
y = 10; z = 20 + x - y
print('Declarar várias variáveis na mesma linha:', y,z)
# Out:
# Declarar várias variáveis na mesma linha: 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print('x',type(x))

nome = 'Thaís'
print('nome',type(nome))

num = '100'
num_convert = int(num)   # Converter variável
print('num',type(num))
print('num_conver', type(num_convert))

num_float = float(num)
print('num_float', type(num_float))
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_conver <class 'int'>
# num_float <class 'float'>

# %% [markdown]
# Input
#
# *   Armazenar a informação digitada pelo usuário em uma variável
# *   O dado armazenado sempre será um texto

# %%
nome = input("Digite o nome do usuário ") # Aguarde o usuário digitar algo
print(nome)

# %%
valor_str = input('Digite a nota ')
print(nome, 'sua nota foi', valor_str)

# %%
valor = input('Digite o valor do produto: ')
valor = float(valor.replace(',', '.'))

print(valor)

# %%
desconto = float(valor) - 5
print(desconto)
