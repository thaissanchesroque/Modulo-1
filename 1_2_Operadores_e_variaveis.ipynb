# %% [markdown]
# <a href="https://colab.research.google.com/github/thaissanchesroque/Modulo-1/blob/main/1_2_Operadores_e_variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Operadores Aritméticos**

# %%
#Adição
10+2
# Out:
# 7

# %%
#Subtração
10-2
# Out:
# 8

# %%
#Multiplicação
10*2
# Out:
# 20

# %%
#Divisão
10/2
# Out:
# 5.0

# %%
#Divisão Inteira
10//2
# Out:
# 5

# %%
#Resto da Divisão
11 % 2
# Out:
# 1

# %%
#Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # **Operadores Relacionais**

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou Igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou Igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 != 7
# Out:
# False

# %% [markdown]
# # **Operadores Lógicos**
#
# *   And
# *   Or
# *   Not

# %% [markdown]
# # Tabela Verdade

# %% [markdown]
# And

# %%
print(10 > 2 and 4 < 6) # V and V - V
print(10 > 2 and 4 > 6) # V and F - F
print(10 < 2 and 4 < 6) # V and F - F
print(10 < 2 and 4 > 6) # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
print(10 > 2 or 4 < 6) # V or V - V
print(10 > 2 or 4 > 6) # V or F - V
print(10 < 2 or 4 < 6) # V or F - V
print(10 < 2 or 4 > 6) # F or F - F
# Out:
# True
# True
# True
# False

# %% [markdown]
# Not

# %%
not 10 > 2 # V - F
# Out:
# False

# %%
not 10 < 2 # F - V
# Out:
# True
